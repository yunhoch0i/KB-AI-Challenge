# %%
import chatbot
chatbot.main()
# Out:
# 최윤호님의 다양한 소비 패턴을 고려하여 KB국민카드에서는 KB 국민카드 The LIVE가 적합할 수 있습니다.
#
# KB 국민카드 The LIVE는 생활 속 다양한 카테고리에서 혜택을 받을 수 있도록 설계되었습니다. 최윤호님이 Sports, Health, Food, Entertainment, Clothes, Movie, OTT, Travel 등 다양한 분야에서 지출을 하고 계신다면, 이 카드를 통해 다양한 즐거움과 혜택을 누릴 수 있을 것입니다.
#
# 또한, KB 국민카드 The LIVE는 특정 카테고리별로 적용되는 할인 혜택과 포인트 적립 프로그램을 제공해 소비자들이 다양한 이익을 누릴 수 있도록 도와줍니다. 따라서, 최윤호님이 다양한 활동을 즐기시고 다른 분야에서도 소비를 하실 때 많은 혜택을 받아보고 싶다면 KB 국민카드 The LIVE를 고려해보세요.
# 대화를 종료합니다.

# %%
import chatbot
chatbot.main()
# Out:
# 이시우님의 이번 달 소비 내역은 다음과 같습니다:
# Food: 1289874원
# Clothes: 1861264원
# None: 4159423원
# Entertainment: 2082201원
# Travel: 876345원
# Health: 2156710원
# Education: 1908933원
# Sports: 2420138원
# OTT: 1814485원
# Oil: 2040765원
# Tax: 3549908원
# Movie: 2677149원
#
# 대화를 종료합니다.

# %%
import chatbot
chatbot.main()
# Out:
# 고객 김가은님의 소득 수준은 78이고, 총 소비한 금액은 27,810,323원입니다. 소득 수준이 비슷한 고객들을 찾아보았습니다. 비슷한 소득 수준을 가진 고객들의 소비 데이터는 아래와 같습니다:
#
# 1. 이름: 김갑숙, 소득 수준: 76, 총 소비 금액: 27,613,363원
# 2. 이름: 정범진, 소득 수준: 84, 총 소비 금액: 23,501,345원
# 3. 이름: 이상우, 소득 수준: 79, 총 소비 금액: 25,713,070원
# 4. 이름: 김둘순, 소득 수준: 85, 총 소비 금액: 27,125,122원
# 5. 이름: 이둘순, 소득 수준: 62, 총 소비 금액: 23,330,105원
#
# 이와 같이 비슷한 소득 수준을 가진 고객들의 소비 데이터를 확인할 수 있습니다. 어떤 부분에 대해 더 자세히 알고 싶으신가요?
# 대화를 종료합니다.

# %%
import chatbot
chatbot.main()
# Out:
# 주식 투자는 기업의 주식을 구매하여 보유하는 행위이며, 선물거래는 미래의 가격을 예측하고 거래하는 금융상품을 말합니다.
#
# 주어진 소비 패턴을 고려하여 KB국민카드 중에서는 KB 국민 올림 신용카드를 추천해드립니다. 이 카드는 다양한 상품 및 서비스에서 적립 및 할인 혜택을 받을 수 있으며, 국민카드 포인트 적립 및 사용이 가능한 특전도 제공됩니다.
#
# 또한, 교육에 많은 비용을 지출하는 것으로 보아 국민은행에서 제공하는 학습장려 신용카드도 고려해볼 만합니다. 이 카드는 교육 관련 지출 시 학습장려포인트 적립 혜택을 받을 수 있어서 학습 비용을 조금이라도 절약할 수 있을 것입니다.
# 대화를 종료합니다.
